# %%
from __future__ import division, print_function, absolute_import
from past.builtins import basestring

import os

import pandas as pd

from twip.constant import DATA_PATH

# %%
import matplotlib
from IPython.display import display, HTML 
# %matplotlib inline
np = pd.np
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_rows', 6)
pd.set_option('display.max_columns', 250)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_csv(os.path.join(DATA_PATH, 'cleaned_tweets.csv.gz'), low_memory=False)
rawlen = len(df)
df.drop_duplicates('id_str', keep='last', inplace=True)
rawlen - len(df)
# Out:
# 10308

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-5ad8e3ee2856> in <module>()
# ----> 1 df.dtype
#
# /home/hobs/.virtualenvs/twip/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
# df.get_
df.get_dtype_counts()
# Out:
# bool        15
# float64     51
# int64       12
# object     209
# dtype: int64

# %%
dtypes = pd.Series([df[v].dtype for v in df.columns], index=df.columns)
dtypes
# Out:
# Unnamed: 0                   int64
# id                           int64
# coordinates_coordinates     object
#                             ...
# user_url                    object
# user_utc_offset            float64
# user_verified                 bool
# dtype: object

# %%
mask = [col for col in df.columns if df[col].dtype in (bool, float, np.dtype('int64'))]  # don't forget bool and int64 (not int)!
mask
numbers = df[mask]
numbers
# Out:
#         Unnamed: 0                  id  favorite_count favorited  \
# 87              87  724276510626979840               0     False
# 88              88  724276498249572352               0     False
# 90              90  724276388325412866               1     False
# ...            ...                 ...             ...       ...
# 193375      193375  724275609858392066               0     False
# 193376      193376  724275578879111169               0     False
# 193377      193377  724275568871673857               0     False
#
#                     id_str  in_reply_to_status_id  in_reply_to_status_id_str  \
# 87      724276510626979840                    NaN                        NaN
# 88      724276498249572352                    NaN                        NaN
# 90      724276388325412866                    NaN                        NaN
# ...                    ...                    ...                        ...
# 193375  724275609858392066                    NaN                        NaN
# 193376  724275578879111169                    NaN                        NaN
# 193377  724275568871673857                    NaN                        NaN
#
#         in_reply_to_user_id  in_reply_to_user_id_str is_quote_status  lat  \
# 87                      NaN                      NaN           False  NaN
# 88                      NaN                      NaN           False  NaN
# 90                      NaN                      NaN           False  NaN
# ...                     ...                      ...             ...  ...
# 193375                  NaN                      NaN           False  NaN
# 193376                  NaN                      NaN           False  NaN
# 193377                  NaN                      NaN           False  NaN
#
#         lon  quoted_status_favorite_count  quoted_status_id  \
# 87      NaN                           NaN               NaN
# 88      NaN                           NaN               NaN
# 90      NaN                           NaN               NaN
# ...     ...                           ...               ...
# 193375  NaN                           NaN               NaN
# 193376  NaN                           NaN               NaN
# 193377  NaN                           NaN               NaN
#
#         quoted_status_id_str  quoted_status_retweet_count  \
# 87                       NaN                          NaN
# 88                       NaN                          NaN
# 90                       NaN                          NaN
# ...                      ...                          ...
# 193375                   NaN                          NaN
# 193376                   NaN                          NaN
# 193377                   NaN                          NaN
#
#         quoted_status_user_favourites_count  \
# 87                                      NaN
# 88                                      NaN
# 90                                      NaN
# ...                                     ...
# 193375                                  NaN
# 193376                                  NaN
# 193377                                  NaN
#
#         quoted_status_user_followers_count  quoted_status_user_friends_count  \
# 87                                     NaN                               NaN
# 88                                     NaN                               NaN
# 90                                     NaN                               NaN
# ...                                    ...                               ...
# 193375                                 NaN                               NaN
# 193376                                 NaN                               NaN
# 193377                                 NaN                               NaN
#
#         quoted_status_user_id  quoted_status_user_id_str  \
# 87                        NaN                        NaN
# 88                        NaN                        NaN
# 90                        NaN                        NaN
# ...                       ...                        ...
# 193375                    NaN                        NaN
# 193376                    NaN                        NaN
# 193377                    NaN                        NaN
#
#         quoted_status_user_listed_count  quoted_status_user_statuses_count  \
# 87                                  NaN                                NaN
# 88                                  NaN                                NaN
# 90                                  NaN                                NaN
# ...                                 ...                                ...
# 193375                              NaN                                NaN
# 193376                              NaN                                NaN
# 193377                              NaN                                NaN
#
#         quoted_status_user_utc_offset  quoted_status_id.1  \
# 87                                NaN                 NaN
# 88                                NaN                 NaN
# 90                                NaN                 NaN
# ...                               ...                 ...
# 193375                            NaN                 NaN
# 193376                            NaN                 NaN
# 193377                            NaN                 NaN
#
#         quoted_status_id_str.1  retweet_count retweeted  \
# 87                         NaN              0     False
# 88                         NaN              0     False
# 90                         NaN              0     False
# ...                        ...            ...       ...
# 193375                     NaN              6     False
# 193376                     NaN              0     False
# 193377                     NaN              0     False
#
#         retweeted_status_favorite_count  retweeted_status_id  \
# 87                                  NaN                  NaN
# 88                                  NaN                  NaN
# 90                                  NaN                  NaN
# ...                                 ...                  ...
# 193375                             10.0         7.242686e+17
# 193376                              NaN                  NaN
# 193377                              NaN                  NaN
#
#         retweeted_status_id_str  retweeted_status_in_reply_to_status_id  \
# 87                          NaN                                     NaN
# 88                          NaN                                     NaN
# 90                          NaN                                     NaN
# ...                         ...                                     ...
# 193375             7.242686e+17                                     NaN
# 193376                      NaN                                     NaN
# 193377                      NaN                                     NaN
#
#         retweeted_status_in_reply_to_status_id_str  \
# 87                                             NaN
# 88                                             NaN
# 90                                             NaN
# ...                                            ...
# 193375                                         NaN
# 193376                                         NaN
# 193377                                         NaN
#
#         retweeted_status_in_reply_to_user_id  \
# 87                                       NaN
# 88                                       NaN
# 90                                       NaN
# ...                                      ...
# 193375                                   NaN
# 193376                                   NaN
# 193377                                   NaN
#
#         retweeted_status_in_reply_to_user_id_str  \
# 87                                           NaN
# 88                                           NaN
# 90                                           NaN
# ...                                          ...
# 193375                                       NaN
# 193376                                       NaN
# 193377                                       NaN
#
#         retweeted_status_quoted_status_favorite_count  \
# 87                                                NaN
# 88                                                NaN
# 90                                                NaN
# ...                                               ...
# 193375                                            NaN
# 193376                                            NaN
# 193377                                            NaN
#
#         retweeted_status_quoted_status_id  \
# 87                                    NaN
# 88                                    NaN
# 90                                    NaN
# ...                                   ...
# 193375                                NaN
# 193376                                NaN
# 193377                                NaN
#
#         retweeted_status_quoted_status_id_str  \
# 87                                        NaN
# 88                                        NaN
# 90                                        NaN
# ...                                       ...
# 193375                                    NaN
# 193376                                    NaN
# 193377                                    NaN
#
#         retweeted_status_quoted_status_retweet_count  \
# 87                                               NaN
# 88                                               NaN
# 90                                               NaN
# ...                                              ...
# 193375                                           NaN
# 193376                                           NaN
# 193377                                           NaN
#
#         retweeted_status_quoted_status_user_favourites_count  \
# 87                                                    NaN
# 88                                                    NaN
# 90                                                    NaN
# ...                                                   ...
# 193375                                                NaN
# 193376                                                NaN
# 193377                                                NaN
#
#         retweeted_status_quoted_status_user_followers_count  \
# 87                                                    NaN
# 88                                                    NaN
# 90                                                    NaN
# ...                                                   ...
# 193375                                                NaN
# 193376                                                NaN
# 193377                                                NaN
#
#         retweeted_status_quoted_status_user_friends_count  \
# 87                                                    NaN
# 88                                                    NaN
# 90                                                    NaN
# ...                                                   ...
# 193375                                                NaN
# 193376                                                NaN
# 193377                                                NaN
#
#         retweeted_status_quoted_status_user_id  \
# 87                                         NaN
# 88                                         NaN
# 90                                         NaN
# ...                                        ...
# 193375                                     NaN
# 193376                                     NaN
# 193377                                     NaN
#
#         retweeted_status_quoted_status_user_id_str  \
# 87                                             NaN
# 88                                             NaN
# 90                                             NaN
# ...                                            ...
# 193375                                         NaN
# 193376                                         NaN
# 193377                                         NaN
#
#         retweeted_status_quoted_status_user_listed_count  \
# 87                                                   NaN
# 88                                                   NaN
# 90                                                   NaN
# ...                                                  ...
# 193375                                               NaN
# 193376                                               NaN
# 193377                                               NaN
#
#         retweeted_status_quoted_status_user_statuses_count  \
# 87                                                    NaN
# 88                                                    NaN
# 90                                                    NaN
# ...                                                   ...
# 193375                                                NaN
# 193376                                                NaN
# 193377                                                NaN
#
#         retweeted_status_quoted_status_user_utc_offset  \
# 87                                                 NaN
# 88                                                 NaN
# 90                                                 NaN
# ...                                                ...
# 193375                                             NaN
# 193376                                             NaN
# 193377                                             NaN
#
#         retweeted_status_quoted_status_id.1  \
# 87                                      NaN
# 88                                      NaN
# 90                                      NaN
# ...                                     ...
# 193375                                  NaN
# 193376                                  NaN
# 193377                                  NaN
#
#         retweeted_status_quoted_status_id_str.1  \
# 87                                          NaN
# 88                                          NaN
# 90                                          NaN
# ...                                         ...
# 193375                                      NaN
# 193376                                      NaN
# 193377                                      NaN
#
#         retweeted_status_retweet_count  \
# 87                                 NaN
# 88                                 NaN
# 90                                 NaN
# ...                                ...
# 193375                             6.0
# 193376                             NaN
# 193377                             NaN
#
#         retweeted_status_user_favourites_count  \
# 87                                         NaN
# 88                                         NaN
# 90                                         NaN
# ...                                        ...
# 193375                                 23339.0
# 193376                                     NaN
# 193377                                     NaN
#
#         retweeted_status_user_followers_count  \
# 87                                        NaN
# 88                                        NaN
# 90                                        NaN
# ...                                       ...
# 193375                                 5678.0
# 193376                                    NaN
# 193377                                    NaN
#
#         retweeted_status_user_friends_count  retweeted_status_user_id  \
# 87                                      NaN                       NaN
# 88                                      NaN                       NaN
# 90                                      NaN                       NaN
# ...                                     ...                       ...
# 193375                                 39.0               745911914.0
# 193376                                  NaN                       NaN
# 193377                                  NaN                       NaN
#
#         retweeted_status_user_id_str  retweeted_status_user_listed_count  \
# 87                               NaN                                 NaN
# 88                               NaN                                 NaN
# 90                               NaN                                 NaN
# ...                              ...                                 ...
# 193375                   745911914.0                               682.0
# 193376                           NaN                                 NaN
# 193377                           NaN                                 NaN
#
#         retweeted_status_user_statuses_count  \
# 87                                       NaN
# 88                                       NaN
# 90                                       NaN
# ...                                      ...
# 193375                               11640.0
# 193376                                   NaN
# 193377                                   NaN
#
#         retweeted_status_user_utc_offset truncated user_contributors_enabled  \
# 87                                   NaN     False                     False
# 88                                   NaN     False                     False
# 90                                   NaN     False                     False
# ...                                  ...       ...                       ...
# 193375                          -10800.0     False                     False
# 193376                               NaN     False                     False
# 193377                               NaN     False                     False
#
#        user_default_profile user_default_profile_image  user_favourites_count  \
# 87                     True                      False                      0
# 88                    False                      False                     56
# 90                    False                      False                  12475
# ...                     ...                        ...                    ...
# 193375                 True                      False                    161
# 193376                False                      False                    105
# 193377                False                      False                      1
#
#         user_followers_count  user_friends_count user_geo_enabled  \
# 87                         1                  12            False
# 88                       454                 197             True
# 90                      3110                4998            False
# ...                      ...                 ...              ...
# 193375                   867                   2            False
# 193376                   819                 275             True
# 193377                    61                  15            False
#
#        user_has_extended_profile     user_id  user_id_str  \
# 87                          True  2957565833   2957565833
# 88                         False    86312900     86312900
# 90                         False  1391270923   1391270923
# ...                          ...         ...          ...
# 193375                     False  3428977365   3428977365
# 193376                     False   385181009    385181009
# 193377                     False   302987528    302987528
#
#        user_is_translation_enabled user_is_translator  user_listed_count  \
# 87                           False              False                  3
# 88                           False              False                  5
# 90                           False              False                 60
# ...                            ...                ...                ...
# 193375                       False              False               1514
# 193376                       False              False                  1
# 193377                       False              False                  4
#
#        user_profile_background_tile user_profile_use_background_image  \
# 87                            False                              True
# 88                             True                              True
# 90                            False                              True
# ...                             ...                               ...
# 193375                        False                              True
# 193376                         True                              True
# 193377                        False                              True
#
#        user_protected  user_statuses_count  user_utc_offset user_verified
# 87              False                  182              NaN         False
# 88              False               117794          25200.0         False
# 90              False                23206         -14400.0         False
# ...               ...                  ...              ...           ...
# 193375          False                10422              NaN         False
# 193376          False                59510          25200.0         False
# 193377          False                  124          28800.0         False
#
# [183070 rows x 78 columns]

# %%
numbers.to_csv(os.path.join(DATA_PATH, 'numbers.csv.gz'), compression='gzip')
